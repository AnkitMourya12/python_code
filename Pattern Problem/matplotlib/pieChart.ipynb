# %%
import matplotlib.pyplot as plt

# %%
course=['python','DSA','Automata','M2','DBMS']
marks=[90,80,50,49,60]
explode=[0,0,0.1,.1,0]
plt.title("course analysis")
plt.pie(marks,labels=course,explode=explode,autopct="%.2f%%")
plt.show()
